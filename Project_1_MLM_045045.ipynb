# %% [markdown]
# # **REPORT**
#
# # **1. Project Objectives | Problem Statements**
#
# 1.1. PO1 | PS1: Ranking of US countries on a variety of health factors using Unsupervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters
#
# 1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics

# %% [markdown]
# # **2. Description of Data**
#
# **2.1. Data Source, Size, Shape**
#
# 2.1.1. Data Source
#
#     (https://public.tableau.com/app/sample-data/County_Health_Rankings.csv?_gl=1*1uo8pl5*_ga*MTY0ODQzNTU4Ny4xNzEwMjM0ODM2*_ga_8YLN0SNXVS*MTcxMTMwMTEzNC41LjAuMTcxMTMwMTEzNC4wLjAuMA..)
#      U.S. County Health Rankings
#
# 2.1.2. Data Size (25.4 MB)
#
# 2.1.3. Data Shape (Dimension: Number of Variables = 14 | Number of Records = 303864)
#
# **2.2. Description of Variables**
#
# 2.2.1. Index Variable(s): 0, 1, 2, 3, ....(auto-generated)
#
# 2.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)
#
#     2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Measure Name, State code, County code, County, State, Measure id
#
#     2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Year Span, Data Release Year
#
# 2.2.3. Non-Categorical Variables or Features: Numerator, Denominator, Raw Value, Confidence Interval Lower Bound, Confidence Interval Upper Bound, fipscode
#
# **2.3. Descriptive Statistics**
#
# 2.3.1. Descriptive Statistics: Categorical Variables or Features
#
# 2.3.1.1. Count | Frequency Statistics
#
#   **Count of Unique Values in Categorical Features:**
#
#   Data Release Year Distribution:
#
# 1. 2010: 15,963 entries
# 2. 2011: 31,926 entries
# 3. 2012: 35,115 entries
# 4. 2013: 31,923 entries
# 5. 2014: 35,202 entries
#
#
#  Measure name distribution:
#
# 1. Children in poverty: 41,499 entries
# 2. Premature Death: 38,312 entries
# 3. Unemployment: 35,202 entries
# 4. Daily fine particulate matter: 28,728 entries
# 5. Violent crime rate: 22,351 entries
# 6. Physical inactivity: 22,351 entries
# 7. Adult obesity: 22,351 entries
# 8. Diabetic screening: 19,159 entries
# 9. Mammography screening: 19,159 entries
# 10. Preventable hospital stays: 19,159 entries
# 11. Uninsured: 19,156 entries
# 12. Sexually transmitted infections: 15,963 entries
#
#
#   Measure ID Distribution:
#
# 1. Measure ID 24.0: 41,499 entries
# 2. Measure ID 1.0: 38,312 entries
# 3. Measure ID 23.0: 35,202 entries
# 4. Measure ID 125.0: 28,728 entries
# 5. Measure ID 43.0: 22,351 entries
# 6. Measure ID 70.0: 22,351 entries
# 7. Measure ID 11.0: 22,351 entries
# 8. Measure ID 7.0: 19,159 entries
# 9. Measure ID 50.0: 19,159 entries
# 10. Measure ID 5.0: 19,159 entries
# 11. Measure ID 85.0: 19,156 entries
# 12. Measure ID 45.0: 15,963 entries
#
#
# 2.3.1.2. Proportion (Relative Frequency) Statistics
#
# **Proportion of Unique Values in Categorical Features:**
#
# Data Release Year Distribution:
#
# 1. 2010: 11.0%
# 2. 2011: 21.0%
# 3. 2012: 23.0%
# 4. 2013: 21.0%
# 5. 2014: 23.0%
#
# Measure Name Distribution:
#
# 1. Children in poverty: 14.0%
# 2. Premature Death: 13.0%
# 3. Unemployment: 12.0%
# 4. Daily fine particulate matter: 9.0%
# 5. Violent crime rate: 7.0%
# 6. Physical inactivity: 7.0%
# 7. Adult obesity: 7.0%
# 8. Diabetic screening: 6.0%
# 9. Mammography screening: 6.0%
# 10. Preventable hospital stays: 6.0%
# 11. Uninsured: 6.0%
# 12. Sexually transmitted infections: 5.0%
#
# Measure ID Distribution:
#
# 1. Measure ID 24.0: 14.0%
# 2. Measure ID 1.0: 13.0%
# 3. Measure ID 23.0: 12.0%
# 4. Measure ID 125.0: 9.0%
# 5. Measure ID 43.0: 7.0%
# 6. Measure ID 70.0: 7.0%
# 7. Measure ID 11.0: 7.0%
# 8. Measure ID 7.0: 6.0%
# 9. Measure ID 50.0: 6.0%
# 10. Measure ID 5.0: 6.0%
# 11. Measure ID 85.0: 6.0%
# 12. Measure ID 45.0: 5.0%
#
#
# 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
#
# 2.3.2.1. Measures of Central Tendency
#
# **Mean**
#
# 1. fipscode   :  30456.873139
# 2. Raw value  :   1075.912013
# 3. State code  :      30.351807
# 4. County code  :    101.981422
#
# 2.3.2.2. Measures of Dispersion
#
# **Standard deviation :**
#
# 1. fipscode    :   15258.982388
# 2. Raw value    :   2851.499091
# 3. State code    :    15.238258
# 4. County code    :  107.824989
#
# 2.3.2.3. Correlation Statistics (with Test of Correlation)
#
# **Correlation Matrix**
#
# 1. 'State code' and 'fipscode': 0.999975698987016
# 2. 'fipscode' and 'County code': 0.17007617185807164
# 3. 'fipscode' and 'Raw value': -0.013749324852586472
# 4. 'County code' and 'Raw value': 0.01278616485734489

# %% [markdown]
# # **3.1 Data Pre-Processing**
#
# 3.1.1. Missing Data Statistics and Treatment
#
# *   **Variable-wise Missing Data Information:**
#
# 1. State: 6 missing values
# 2. County: 6 missing values
# 3. State code: 4 missing values
# 4. County code: 4 missing values
# 5. Year span: 474 missing values
# 6. Measure name: 474 missing values
# 7. Measure id: 474 missing values
# 8. Numerator: 89,788 missing values
# 9. Denominator: 119,085 missing values
# 10. Raw value: 13,908 missing values
# 11. Confidence Interval Lower Bound: 114,452 missing values
# 12. Confidence Interval Upper Bound: 114,452 missing values
# 13. Data Release Year: 153,735 missing values
# 14. fipscode: 9,581 missing values
#
# *   **Record-wise Missing Data Information (Top 5 Records):**
#
# 1. Record 191961: 9 missing values
# 2. Record 175912: 9 missing values
# 3. Record 99123: 9 missing values
# 4. Record 99122: 9 missing values
# 5. Record 99121: 9 missing values
#
# 3.1.2. Numerical Encoding of Categorical Variables or Features
#
# **Ordinal Encoder:** Used to encode categorical variables into numerical format.
#
# 3.1.3. Outlier Statistics and Treatment
#
# **Outlier Detection:** Identified outliers using boxplot visualization.
#
# **Outlier Treatment:** Outliers treated by performing normalization using Min-Max Scaler.
#
# 3.1.4. Data Transformation and Scaling
#
# Normalization: Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# 3.1.5. Pre-Processed Dataset
#
# **Pre-Processed Categorical Data Subset:** Encoded categorical data using Ordinal Encoder.
#
# **Pre-Processed Non-Categorical Data Subset:** Normalized non-categorical data using Min-Max Scaler.
#
# **Pre-Processed Dataset:** Merged pre-processed categorical and non-categorical data subsets.
#
# **Note:** No data bifurcation into training and testing sets was required as part of this analysis.

# %% [markdown]
# # **3.2 Data Analysis**
#
# **3.2.1. Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance**
#
#
# K-Means clustering is a method used to group data points into K clusters, with each cluster having similar characteristics. This clustering is based on the Euclidean distance metric, which measures the distance between data points in a multi-dimensional space. The selection of K, the number of clusters, plays a crucial role in determining the level of granularity in the clustering process and the interpretability of the resulting clusters.
#
# **3.2.2. Clustering Model Performance Evaluation**
#
# **3.2.2.1. K Means Clustering Using the Elbow Method**
#
#
# In the Elbow method, we explore a range of potential cluster numbers (K) from 1 to 10 and compute the Within-Cluster Sum of Squares (WCSS) for each value of K. WCSS quantifies the dispersion of data points within clusters by summing the squared distances between each point and its cluster centroid. By plotting the WCSS against the number of clusters, we observe a curve that resembles an "Elbow." The optimal number of clusters is determined at the point where the curve displays a sharp change in slope before leveling off, indicating diminishing returns in reducing WCSS as we increase the number of clusters. This optimal point suggests the most appropriate number of clusters for the given dataset.
#
# **3.2.2.2. Silhouette Score | Davies-Bouldin Score (Base Model: K-Means)**
#
# *   **Silhouette Score:** Measures the cohesion and separation of clusters, with values ranging from -1 to 1. Higher scores indicate better-defined clusters.
#
# *   **Davies-Bouldin Index:** Measures the average similarity between each cluster and its most similar cluster. Lower values suggest better clustering.
#
# **3.2.2.3. Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Means)**
#
# **Time Statistics:** Includes the time taken by the K-Means algorithm to converge for a given number of clusters.
#
# **Memory Statistics:** Refers to the memory consumption (CPU or GPU) by the K-Means algorithm during execution.
#
# # **Detailed Analysis**
#
# - **For 2 clusters**:
#   - Silhouette Score : 0.5963928385227006
#   - Davies-Bouldin Index : 0.5400086053229081
# - **For 3 clusters** :
#   - Silhouette Score : 0.5538051551421037
#   - Davies-Bouldin Index : 0.5845355397164748
# - **For 4 clusters** :
#   - Silhouette Score : 0.523645179540842
#   - Davies-Bouldin Index : 0.6199668610926679
# - **For 5 clusters** (Chosen Optimal) :
#   - Silhouette Score : 0.5620858540321584
#   - Davies-Bouldin Index : 0.5668631851224781
#
# **Time and Memory Statistics Analysis:**
#
# - **For k=5** (Chosen Optimal):
#   - Time taken by K-Means for k=5: 2.3788 seconds
#   - Memory used by K-Means for k=5: 696.94 MB
#
# This analysis showcases the computational efficiency and resource requirements of K-Means, guiding the selection of an appropriate cluster size.
#
# **Conclusion**
#
# Based on comprehensive evaluation metrics, K=3 is identified as the optimal cluster count, balancing clustering quality and computational efficiency. Theoretical insights into metrics enrich understanding, aiding informed decision-making. The Elbow method confirms K=4, ensuring a robust approach to cluster analysis.

# %% [markdown]
# # **3.2.3.1. PO3 | PS3:: Cluster Analysis: Base Model (K-Means)**
#
#
#
#
# The Chi-Square Test of Independence is a statistical test used to determine whether there is a significant association between two categorical variables. In this context, the test is applied to assess the relationship between each categorical variable (e.g., 'Measure name','Year span','Data Release Year','Measure id') and other variables in the dataset.
#
#     Chi-Square Test of Independence for variable 'Measure name':
#         - Chi-Square Value: 8258.3737401463
#         - P-value: 0.0
#     Chi-Square Test of Independence for variable 'Data Release Year':
#         - Chi-Square Value:  715.9166771867621
#         - P-value: 5.291977959937061e-142
#     Chi-Square Test of Independence for variable 'Year span':
#         - Chi-Square Value: 8519.116266829938
#         - P-value: 0.0
#     Chi-Square Test of Independence for variable 'Measure id':
#         - Chi-Square Value: 8258.3737401463
#         - P-value: 0.0
#
# The results of the Chi-Square Test of Independence are interpreted as follows:
#
# **Chi-Square Value:** This value indicates the strength of the association between the two categorical variables. Higher values suggest a stronger association, while lower values suggest a weaker association.
#
# **P-value:** The P-value indicates the probability of observing the data given that the null hypothesis is true, i.e., there is no association between the two variables. A small P-value (typically less than 0.05) suggests that the association is statistically significant, indicating that we can reject the null hypothesis and conclude that there is an association between the variables.
#
# **INTERPRETATION:**
#
# **Measure name:**
#
#   The Chi-Square value of 8258.37 with a p-value of 0.0 suggests a significant association between the 'Measure name' and the cluster labels.
#   It indicates that the choice of 'Measure name' significantly influences the clustering outcome.
#
# **Data Release Year:**
#
# The Chi-Square value of 715.92 with a p-value of  5.292e-142 indicates a significant association between the 'Data Release Year' and the cluster labels.
# The extremely low p-value ( 5.292e-142) provides strong evidence against the null hypothesis, suggesting that the 'Data Release Year_code' is not independent of the other variable(s) being analyzed.
#
# **Year span:**
#
# The Chi-Square value of  8519.12 with a p-value of 0.0 suggests a significant association between the 'Year span' and the cluster labels.
# This indicates that the duration covered by the data significantly affects the clustering.
#
# **Measure id:**
#
# The Chi-Square value of 8258.37 with a p-value of 0.0 indicates a significant association between the 'Measure id' and the cluster labels.
# It implies that the specific 'Measure id' plays a significant role in determining the cluster assignments.
#
# ---
#
# The Chi-Square Test of Independence outcomes offer valuable insights into the relationship between categorical variables and the clusters identified through K-Means clustering, which can be interpreted as follows:
#
# **Significant Associations:** Notable connections between clusters and categorical variables indicate the clustering algorithm's success in capturing inherent data patterns. This suggests that clusters are meaningful segments rather than arbitrary groupings, displaying distinct traits based on the categorical variables.
#
# **Informative Features:** The observed associations imply that categorical variables (e.g., Measure name, Measure id, Data Release Year, Year span) play a substantial role in clustering. They effectively differentiate between clusters, contributing to more interpretable and actionable results.
#
# **Enhanced Interpretability:** Strong associations between clusters and categorical variables improve the interpretability of clustering outcomes. Analysts can leverage these associations to understand each cluster's characteristics and behaviors, enabling more targeted analysis and decision-making.
#
# **Validity of Clusters:** The significance of these associations validates the clustering algorithm's efficacy in segregating data into meaningful groups based on both categorical and numerical variables. It confirms that the identified clusters reflect genuine distinctions or similarities within the data.
#
# **3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
#
#     Cluster 2 ANOVA Results:
#        - Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
#        - fipscode: F-value = 1886512.2425557615, p-value = 0.0
#        - Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
#     Cluster 3 ANOVA Results:
#        - Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
#          fipscode: F-value = 1886512.2425557615, p-value = 0.0
#          Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
#     Cluster 0 ANOVA Results:
#         Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
#         fipscode: F-value = 1886512.2425557615, p-value = 0.0
#         Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
#     Cluster 4 ANOVA Results:
#         Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
#         fipscode: F-value = 1886512.2425557615, p-value = 0.0
#         Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
#     Cluster 1 ANOVA Results:
#         Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
#         fipscode: F-value = 1886512.2425557615, p-value = 0.0
#         Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
#
#
# The ANOVA results indicate whether there are statistically significant differences in the means of the features across different clusters. Here's what each part of the ANOVA results means:
#
# *   **Cluster Label:** This indicates which cluster the ANOVA results correspond to.
# *   **ANOVA Results for Each Feature:**
#      1. **Raw value_mmnorm:**
# F-value is approximately 103.065.
# The p-value is extremely small (close to zero), indicating strong evidence against the null hypothesis that there is no difference in mean values of Raw value_mmnorm across different clusters. Therefore, we reject the null hypothesis and conclude that there is a significant difference in mean values of Raw value_mmnorm across clusters.
#
#      2. **fipscode:**
# F-value is approximately 1886512.24.
# The p-value is zero, indicating strong evidence against the null hypothesis that there is no difference in mean values of fipscode across different clusters. Therefore, we reject the null hypothesis and conclude that there is a significant difference in mean values of fipscode across clusters.
#
#      3. **Raw value:**
# F-value is approximately 103.065.
# The p-value is extremely small (close to zero), indicating strong evidence against the null hypothesis that there is no difference in mean values of Raw value across different clusters. Therefore, we reject the null hypothesis and conclude that there is a significant difference in mean values of Raw value across clusters.
#
# In summary, for all three features (Raw value_mmnorm, fipscode, Raw value), the ANOVA results suggest that there are significant differences in mean values across different clusters, as indicated by the small p-values and large F-values.

# %% [markdown]
# # **Managerial Implications**
#
# 1. **Identifying High-Risk Areas:** By clustering counties based on health indicators, managers can identify regions with similar health profiles. This information can be used to prioritize resources and interventions in areas with higher health risks.
#
# 2. **Targeted Interventions:** Understanding the characteristics of different clusters can help in designing targeted interventions. For example, if certain clusters have higher rates of preventable diseases, interventions can be tailored to address those specific health issues.
#
# 3. **Resource Allocation:** Managers can use cluster analysis to allocate resources effectively. For instance, counties with higher health needs may require more funding for healthcare facilities, health education programs, or public health campaigns.
#
# 4. **Policy Development:** Insights from the dataset can inform the development of health policies and programs at the local, regional, or national level. Policy decisions can be guided by the specific health challenges identified in different clusters.
#
# 5. **Benchmarking and Performance Evaluation:** Health data analysis allows for benchmarking and performance evaluation across different counties or regions. Managers can assess the effectiveness of health initiatives and track improvements over time by comparing health outcomes between clusters.
#
# 6. **Collaborative Partnerships:** Identifying clusters with similar health challenges can facilitate collaboration between healthcare providers, government agencies, community organizations, and other stakeholders. Collaborative efforts can lead to more coordinated and comprehensive approaches to improving health outcomes.
#
# 7. **Predictive Modeling and Forecasting:** Analyzing historical health data can enable predictive modeling and forecasting of future health trends. This information can help managers anticipate emerging health issues and proactively plan interventions.
#
# 8. **Health Equity:** Managers can use insights from the dataset to address health disparities and promote health equity. By targeting resources to underserved communities or groups within clusters, managers can work towards reducing disparities in health outcomes.
#
# Overall, leveraging county health data for analysis and decision-making can lead to more informed strategies for improving population health, reducing healthcare costs, and enhancing overall well-being.

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939417 sha256=4bdfa0fee59f5f9a216c40fda2cecf5fcbc2c5dde6bc3d571ddb960a09839c8b
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# ...

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import seaborn as sns
import os
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

# %%
df = pd.read_csv("County_Health_Rankings.csv")

# %%
df
# Out:
#        State         County  State code  County code  Year span  \
# 0         US  United States         0.0          0.0  2003-2005
# 1         US  United States         0.0          0.0  2004-2006
# 2         US  United States         0.0          0.0  2005-2007
# 3         US  United States         0.0          0.0  2006-2008
# 4         US  United States         0.0          0.0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303859    WY  Weston County        56.0         45.0       2007
# 303860    WY  Weston County        56.0         45.0       2008
# 303861    WY  Weston County        56.0         45.0       2009
# 303862    WY  Weston County        56.0         45.0       2010
# 303863    WY  Weston County        56.0         45.0       2011
#
#                          Measure name  Measure id    Numerator  Denominator  \
# 0                  Violent crime rate        43.0  1328750.667  274877117.0
# ...

# %%
missing_values = ["NaN"]
df = pd.read_csv("County_Health_Rankings.csv", na_values=missing_values)

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# State                                   6
# County                                  6
# State code                              4
# County code                             4
# Year span                             474
# Measure name                          474
# Measure id                            474
# Numerator                           89788
# Denominator                        119085
# Raw value                           13908
# Confidence Interval Lower Bound    114452
# Confidence Interval Upper Bound    114452
# Data Release Year                  153735
# fipscode                             9581
# dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data
# Out:
# 191961    9
# 175912    9
# 99123     9
# 99122     9
# 99121     9
# dtype: int64

# %%
df.dropna(how="all")
# Out:
#        State         County  State code  County code  Year span  \
# 0         US  United States         0.0          0.0  2003-2005
# 1         US  United States         0.0          0.0  2004-2006
# 2         US  United States         0.0          0.0  2005-2007
# 3         US  United States         0.0          0.0  2006-2008
# 4         US  United States         0.0          0.0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303859    WY  Weston County        56.0         45.0       2007
# 303860    WY  Weston County        56.0         45.0       2008
# 303861    WY  Weston County        56.0         45.0       2009
# 303862    WY  Weston County        56.0         45.0       2010
# 303863    WY  Weston County        56.0         45.0       2011
#
#                          Measure name  Measure id    Numerator  Denominator  \
# 0                  Violent crime rate        43.0  1328750.667  274877117.0
# ...

# %% [markdown]
# # **Data Bifurcation**

# %%
df_cat = df[['State','County','Measure name','Data Release Year','Year span','Measure id']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[[ 'State code','County code','Numerator','Denominator','Raw value','Confidence Interval Lower Bound','Confidence Interval Upper Bound','fipscode']] # Non-Categorical Data

# %%
df_cat
# Out:
#        State         County                   Measure name  Data Release Year  \
# 0         US  United States             Violent crime rate                NaN
# 1         US  United States             Violent crime rate                NaN
# 2         US  United States             Violent crime rate             2010.0
# 3         US  United States             Violent crime rate             2011.0
# 4         US  United States             Violent crime rate             2012.0
# ...      ...            ...                            ...                ...
# 303859    WY  Weston County  Daily fine particulate matter                NaN
# 303860    WY  Weston County  Daily fine particulate matter             2013.0
# 303861    WY  Weston County  Daily fine particulate matter                NaN
# 303862    WY  Weston County  Daily fine particulate matter                NaN
# 303863    WY  Weston County  Daily fine particulate matter             2014.0
#
#         Year span  Measure id
# ...

# %%
df_noncat
# Out:
#         State code  County code    Numerator  Denominator   Raw value  \
# 0              0.0          0.0  1328750.667  274877117.0  483.398066
# 1              0.0          0.0  1340928.667  277612778.5  483.021233
# 2              0.0          0.0  1355853.167  280407694.7  483.529230
# 3              0.0          0.0  1366928.333  287614567.7  475.263942
# 4              0.0          0.0  1339439.333  292576281.2  457.808585
# ...            ...          ...          ...          ...         ...
# 303859        56.0         45.0          NaN          NaN    9.370000
# 303860        56.0         45.0          NaN          NaN    7.450000
# 303861        56.0         45.0          NaN          NaN   12.770000
# 303862        56.0         45.0          NaN          NaN   12.110000
# 303863        56.0         45.0          NaN          NaN   10.710000
#
#         Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# ...

# %% [markdown]
# # **Data Pre-processing**

# %%
si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   State              303864 non-null  object
#  1   County             303864 non-null  object
#  2   Measure name       303864 non-null  object
#  3   Data Release Year  303864 non-null  object
#  4   Year span          303864 non-null  object
#  5   Measure id         303864 non-null  object
# dtypes: object(6)
# memory usage: 13.9+ MB

# %%
si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean')
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si
df_noncat_mdi_si.info()
print(df_noncat_mdi_si)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State code                       303864 non-null  float64
#  1   County code                      303864 non-null  float64
#  2   Numerator                        303864 non-null  float64
#  3   Denominator                      303864 non-null  float64
#  4   Raw value                        303864 non-null  float64
#  5   Confidence Interval Lower Bound  303864 non-null  float64
#  6   Confidence Interval Upper Bound  303864 non-null  float64
#  7   fipscode                         303864 non-null  float64
# dtypes: float64(8)
# memory usage: 18.5 MB
#         State code  County code     Numerator   Denominator   Raw value  \
# 0              0.0          0.0  1.328751e+06  2.748771e+08  483.398066
# ...

# %%
# Excluding Empty Records (If Any)
df_cat_mdi.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset
df_noncat_mdi_si.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset
#df_noncat_mdi_ki.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset

# %%
# Excluding Empty Variables (If Any)
df_cat_mdi.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset
df_noncat_mdi_si.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset
#df_noncat_mdi_ki.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset

# %%
df_cat_mdt = df_cat_mdi.copy() # Missing Categorical Treated Dataset
df_noncat_mdt = df_noncat_mdi_si.copy() # Missing Non-Categorical Treated Dataset
#df_noncat_mdt = df_noncat_mdi_ki.copy() # Missing Non-Categorical Treated Dataset
print(df_noncat_mdt)
# Out:
#         State code  County code     Numerator   Denominator   Raw value  \
# 0              0.0          0.0  1.328751e+06  2.748771e+08  483.398066
# 1              0.0          0.0  1.340929e+06  2.776128e+08  483.021233
# 2              0.0          0.0  1.355853e+06  2.804077e+08  483.529230
# 3              0.0          0.0  1.366928e+06  2.876146e+08  475.263942
# 4              0.0          0.0  1.339439e+06  2.925763e+08  457.808585
# ...            ...          ...           ...           ...         ...
# 303859        56.0         45.0  1.253031e+04  1.354018e+05    9.370000
# 303860        56.0         45.0  1.253031e+04  1.354018e+05    7.450000
# 303861        56.0         45.0  1.253031e+04  1.354018e+05   12.770000
# 303862        56.0         45.0  1.253031e+04  1.354018e+05   12.110000
# 303863        56.0         45.0  1.253031e+04  1.354018e+05   10.710000
#
#         Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# ...

# %%
# Dataset Used : df_cat_mdt
df_cat_mdt_code = df_cat_mdt.copy()

# Using Pandas (Inferior)
df_cat_mdt_code_pd = df_cat_mdt_code.astype('category')
df_cat_mdt_code_pd['Measure name_code'] = df_cat_mdt_code_pd['Measure name'].cat.codes
df_cat_mdt_code_pd['Data Release Year_code'] = df_cat_mdt_code_pd['Data Release Year'].cat.codes
df_cat_mdt_code_pd['Year span_code'] = df_cat_mdt_code_pd['Year span'].cat.codes
df_cat_mdt_code_pd['Measure id_code'] = df_cat_mdt_code_pd['Measure id'].cat.codes
df_cat_mdt_code_pd # (Missing Data Treated) Numeric Coded Categorical Dataset using Pandas
# Out:
#        State         County                   Measure name Data Release Year  \
# 0         US  United States             Violent crime rate            2014.0
# 1         US  United States             Violent crime rate            2014.0
# 2         US  United States             Violent crime rate            2010.0
# 3         US  United States             Violent crime rate            2011.0
# 4         US  United States             Violent crime rate            2012.0
# ...      ...            ...                            ...               ...
# 303859    WY  Weston County  Daily fine particulate matter            2014.0
# 303860    WY  Weston County  Daily fine particulate matter            2013.0
# 303861    WY  Weston County  Daily fine particulate matter            2014.0
# 303862    WY  Weston County  Daily fine particulate matter            2014.0
# 303863    WY  Weston County  Daily fine particulate matter            2014.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['fipscode', 'Raw value']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['fipscode'])
plt.title('Boxplot of fipscode')
plt.ylabel('fipscode')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['Raw value'])
plt.title('Boxplot of Raw value')
plt.ylabel('Raw value')
plt.show()

# %%
#3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit1 = mms.fit_transform(df_noncat_mdt[['fipscode','Raw value']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit1, columns=['fipscode_mmnorm','Raw value_mmnorm']); df_noncat_minmax_norm
#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(df_noncat_mdi_si, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
# Out:
#         State code  County code     Numerator   Denominator   Raw value  \
# 0              0.0          0.0  1.328751e+06  2.748771e+08  483.398066
# 1              0.0          0.0  1.340929e+06  2.776128e+08  483.021233
# 2              0.0          0.0  1.355853e+06  2.804077e+08  483.529230
# 3              0.0          0.0  1.366928e+06  2.876146e+08  475.263942
# 4              0.0          0.0  1.339439e+06  2.925763e+08  457.808585
# ...            ...          ...           ...           ...         ...
# 303859        56.0         45.0  1.253031e+04  1.354018e+05    9.370000
# 303860        56.0         45.0  1.253031e+04  1.354018e+05    7.450000
# 303861        56.0         45.0  1.253031e+04  1.354018e+05   12.770000
# 303862        56.0         45.0  1.253031e+04  1.354018e+05   12.110000
# 303863        56.0         45.0  1.253031e+04  1.354018e+05   10.710000
#
#         Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# ...

# %%
df_cat_mdt_code = df_cat_mdt.copy()

# %%
# Pre-Processed Dataset
df_ppd = pd.merge(df_cat_mdt_code_pd, df_noncat_mdt_mmn, left_index=True, right_index=True); df_ppd
# Out:
#        State         County                   Measure name Data Release Year  \
# 0         US  United States             Violent crime rate            2014.0
# 1         US  United States             Violent crime rate            2014.0
# 2         US  United States             Violent crime rate            2010.0
# 3         US  United States             Violent crime rate            2011.0
# 4         US  United States             Violent crime rate            2012.0
# ...      ...            ...                            ...               ...
# 303859    WY  Weston County  Daily fine particulate matter            2014.0
# 303860    WY  Weston County  Daily fine particulate matter            2013.0
# 303861    WY  Weston County  Daily fine particulate matter            2014.0
# 303862    WY  Weston County  Daily fine particulate matter            2014.0
# 303863    WY  Weston County  Daily fine particulate matter            2014.0
#
# ...

# %%
df_ppd = df_ppd.drop(columns=['State', 'County'])
df_ppd
# Out:
#                          Measure name Data Release Year  Year span Measure id  \
# 0                  Violent crime rate            2014.0  2003-2005       43.0
# 1                  Violent crime rate            2014.0  2004-2006       43.0
# 2                  Violent crime rate            2010.0  2005-2007       43.0
# 3                  Violent crime rate            2011.0  2006-2008       43.0
# 4                  Violent crime rate            2012.0  2007-2009       43.0
# ...                               ...               ...        ...        ...
# 303859  Daily fine particulate matter            2014.0       2007      125.0
# 303860  Daily fine particulate matter            2013.0       2008      125.0
# 303861  Daily fine particulate matter            2014.0       2009      125.0
# 303862  Daily fine particulate matter            2014.0       2010      125.0
# 303863  Daily fine particulate matter            2014.0       2011      125.0
#
# ...

# %% [markdown]
# # **K-Means Clustering**

# %%
#K-Means Clustering


# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
train_new_df=df_ppd[['Year span_code',  'Data Release Year_code','Measure id_code',  'Measure name_code',  'fipscode_mmnorm',  'Raw value_mmnorm']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(train_new_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
print(plt.show())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
cluster_range = [2, 3, 4, 5]

# Iterate over different numbers of clusters
for k in cluster_range:
  # Perform Kmeans Clustering
    km_cluster = kmclus(n_clusters=k, init='random', random_state=222)
    print(km_cluster)
    km_cluster_model = km_cluster.fit_predict(train_new_df);
    print(km_cluster_model)
# Calculate Silhouette Score
    sscore_km_cluster = sscore(train_new_df, km_cluster_model);
    print(f"Silhouette Score for {k} clusters: {sscore_km_cluster}")
    # Calculate Davies-Bouldin Index
    dbscore_km_cluster = dbscore(train_new_df, km_cluster_model)
    print(f"Davies-Bouldin Index for {k} clusters: {dbscore_km_cluster}\n")
# Out:
# KMeans(init='random', n_clusters=2, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 1 ... 0 0 0]
# Silhouette Score for 2 clusters: 0.5963928385227006
# Davies-Bouldin Index for 2 clusters: 0.5400086053229081
#
# KMeans(init='random', n_clusters=3, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 1 ... 0 0 0]
# Silhouette Score for 3 clusters: 0.5538051551421037
# Davies-Bouldin Index for 3 clusters: 0.5845355397164748
#
# KMeans(init='random', n_clusters=4, random_state=222)
# ...

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

train_new_df = df_ppd[['fipscode_mmnorm','Raw value_mmnorm', 'Measure name_code', 'Data Release Year_code', 'Year span_code', 'Measure id_code', 'fipscode', 'Raw value']]

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 5

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['Raw value_mmnorm', 'Measure name_code', 'Data Release Year_code', 'Year span_code', 'Measure id_code', 'fipscode', 'Raw value','fipscode_mmnorm']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=5:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=5:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

# Visualize the clusters using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_new_df, x='Raw value_mmnorm', y='fipscode', hue='cluster', palette='viridis', s=100)
plt.scatter(centroids[:, 0], centroids[:, 5], marker='*', s=300, c='black', label='Centroids')
plt.xlabel('Raw value_mmnorm')
plt.ylabel('fipscode')
plt.title('K-means Clustering with Centroids')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=5: 2.3788 seconds
# Memory used by K-Means for k=5: 696.94 MB
# <ipython-input-25-769046567390>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %%
# Further analysis or visualization with cluster labels

# Cluster Analysis with Categorical Variables: Chi-Square Test of Independence
# Assuming you have performed clustering and added cluster labels to your DataFrame 'df'

import pandas as pd
from scipy.stats import chi2_contingency

# Select categorical variables for analysis
categorical_variables = ['Measure name_code','Data Release Year_code','Year span_code','Measure id_code']

# Create a contingency table for each categorical variable and the cluster labels
contingency_tables = {}
for variable in categorical_variables:
    contingency_tables[variable] = pd.crosstab(train_new_df[variable], train_new_df['cluster'])

# Perform Chi-Square Test of Independence for each contingency table
chi2_results = {}
for variable, contingency_table in contingency_tables.items():
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[variable] = {'Chi-Square': chi2, 'P-value': p}

# Display the results
for variable, result in chi2_results.items():
    print(f"Chi-Square Test of Independence for variable '{variable}':")
    print(f"   - Chi-Square Value: {result['Chi-Square']}")
    print(f"   - P-value: {result['P-value']}")
# Out:
# Chi-Square Test of Independence for variable 'Measure name_code':
#    - Chi-Square Value: 8258.3737401463
#    - P-value: 0.0
# Chi-Square Test of Independence for variable 'Data Release Year_code':
#    - Chi-Square Value: 715.9166771867621
#    - P-value: 5.291977959937061e-142
# Chi-Square Test of Independence for variable 'Year span_code':
#    - Chi-Square Value: 8519.116266829938
#    - P-value: 0.0
# Chi-Square Test of Independence for variable 'Measure id_code':
#    - Chi-Square Value: 8258.3737401463
#    - P-value: 0.0

# %%
from scipy.stats import f_oneway

# List of features for ANOVA
numeric_features = ['Raw value_mmnorm', 'fipscode', 'Raw value']

# Initialize an empty dictionary to store ANOVA results
anova_results = {}

# Iterate over unique cluster labels
for cluster_label in train_new_df['cluster'].unique():
    # Filter dataframe for the current cluster
    cluster_df = train_new_df[train_new_df['cluster'] == cluster_label]

    # Initialize an empty dictionary to store ANOVA results for the current cluster
    cluster_anova_results = {}

    # Perform ANOVA for each feature
    for feature in numeric_features:
        # Perform ANOVA test
        anova_result = f_oneway(*[train_new_df[train_new_df['cluster'] == i][feature] for i in train_new_df['cluster'].unique()])
        # Store ANOVA result
        cluster_anova_results[feature] = anova_result

    # Store ANOVA results for the current cluster
    anova_results[cluster_label] = cluster_anova_results

# Print ANOVA results
for cluster_label, cluster_anova_result in anova_results.items():
    print(f"Cluster {cluster_label} ANOVA Results:")
    for feature, result in cluster_anova_result.items():
        print(f"{feature}: F-value = {result.statistic}, p-value = {result.pvalue}")
# Out:
# Cluster 2 ANOVA Results:
# Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
# fipscode: F-value = 1886512.2425557615, p-value = 0.0
# Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
# Cluster 3 ANOVA Results:
# Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
# fipscode: F-value = 1886512.2425557615, p-value = 0.0
# Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
# Cluster 0 ANOVA Results:
# Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
# fipscode: F-value = 1886512.2425557615, p-value = 0.0
# Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
# Cluster 4 ANOVA Results:
# Raw value_mmnorm: F-value = 103.06475944344585, p-value = 7.168314241631723e-88
# fipscode: F-value = 1886512.2425557615, p-value = 0.0
# Raw value: F-value = 103.0647594434458, p-value = 7.168314241631723e-88
# Cluster 1 ANOVA Results:
# ...

# %% [markdown]
# # **PAIR-PLOT**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming train_new_df contains your DataFrame and km_cluster_model contains the cluster labels

# Add cluster labels to DataFrame
train_new_df['cluster'] = km_cluster_model

# List of features for pair plot
features = [ 'Year span', 'Data Release Year', 'Measure id', 'Measure name', 'fipscode_mmnorm', 'Raw value_mmnorm', 'cluster']

# Create pair plot
sns.pairplot(train_new_df[features], diag_kind='kde', hue='cluster', palette='viridis')
plt.suptitle('Pairplot of County Health Data with Clusters', y=1.02)
plt.show()
# Out:
# <ipython-input-96-910737165762>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = km_cluster_model
